# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import regex as re
import unicodedata

# %%
#emojis, url, dates, common stopwords, mixed case text, puntuation, special characters, whitecharacters, numbers,accented characters,

# %%
corpus =''' Hey there! 😃 I can't believe it's already 2024. Did you see John's new blog post? Check it out at https://example.com/blog! Also, email me at john.doe@example.com. He mentioned something about "stemming" and "lemmatization"—interesting stuff. BTW, I'll be attending the AI conference in N.Y.C. next month!! #Excited #AI 😊 Let's catch up soon. Cheers, John" '''

# %%
corpus = corpus.lower()
print(corpus)
# Out:
#  hey there! 😃 i can't believe it's already 2024. did you see john's new blog post? check it out at https://example.com/blog! also, email me at john.doe@example.com. he mentioned something about "stemming" and "lemmatization"—interesting stuff. btw, i'll be attending the ai conference in n.y.c. next month!! #excited #ai 😊 let's catch up soon. cheers, john"

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def clean_corpus(corpus):
    clean_corpus = []
    for text in corpus:
        # Remove proper nouns and names
        text = re.sub(r'\b[A-Z][a-z]+\b', '', corpus)
        # Remove punctuation
        text = re.sub(r'[^\w\s]', '', corpus)
        # Remove URLs
        text = re.sub(r'http\S+', '', text)
        # Remove dates
        text = re.sub(r'\b(?:\d{1,2}[-/]\d{1,2}[-/]\d{2,4}|\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\s\d{1,2}:\d{2}:\d{2})\b', '', text)
        # Remove contractions
        text = re.sub(r'\b(can\'t|won\'t|I\'ll|I\'m|you\'re|he\'s|she\'s|it\'s|we\'re|they\'re)\b', '', text)
        # Remove common stopwords
        stop_words = set(stopwords.words('english'))
        words = word_tokenize(text)
        filtered_text = [word for word in words if word.lower() not in stop_words]
        text = ' '.join(filtered_text)
        # Remove mixed case text
        text = re.sub(r'\b[A-Z][a-z]+\b', '', text)
        # Remove special characters
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        # # Remove white spaces
        # text = re.sub(r'\s+', '', text)
        # Remove numbers
        text = re.sub(r'\d+', '', text)
        # Remove accented characters
        text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8')
        clean_corpus.append(text)

    return clean_corpus

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
clean_text = clean_corpus(corpus)
print(clean_text)
# Out:
# ['hey cant believe already  see johns new blog post check also email johndoeexamplecom mentioned something stemming lemmatizationinteresting stuff btw ill attending ai conference nyc next month excited ai lets catch soon cheers john', 'hey cant believe already  see johns new blog post check also email johndoeexamplecom mentioned something stemming lemmatizationinteresting stuff btw ill attending ai conference nyc next month excited ai lets catch soon cheers john', 'hey cant believe already  see johns new blog post check also email johndoeexamplecom mentioned something stemming lemmatizationinteresting stuff btw ill attending ai conference nyc next month excited ai lets catch soon cheers john', 'hey cant believe already  see johns new blog post check also email johndoeexamplecom mentioned something stemming lemmatizationinteresting stuff btw ill attending ai conference nyc next month excited ai lets catch soon cheers john', 'hey cant believe already  see johns new blog post check also
# ...

# %%
# Tokenize the words
tokenized_text = [word_tokenize(text) for text in clean_text]
print(tokenized_text)
# Out:
# [['hey', 'cant', 'believe', 'already', 'see', 'johns', 'new', 'blog', 'post', 'check', 'also', 'email', 'johndoeexamplecom', 'mentioned', 'something', 'stemming', 'lemmatizationinteresting', 'stuff', 'btw', 'ill', 'attending', 'ai', 'conference', 'nyc', 'next', 'month', 'excited', 'ai', 'lets', 'catch', 'soon', 'cheers', 'john'], ['hey', 'cant', 'believe', 'already', 'see', 'johns', 'new', 'blog', 'post', 'check', 'also', 'email', 'johndoeexamplecom', 'mentioned', 'something', 'stemming', 'lemmatizationinteresting', 'stuff', 'btw', 'ill', 'attending', 'ai', 'conference', 'nyc', 'next', 'month', 'excited', 'ai', 'lets', 'catch', 'soon', 'cheers', 'john'], ['hey', 'cant', 'believe', 'already', 'see', 'johns', 'new', 'blog', 'post', 'check', 'also', 'email', 'johndoeexamplecom', 'mentioned', 'something', 'stemming', 'lemmatizationinteresting', 'stuff', 'btw', 'ill', 'attending', 'ai', 'conference', 'nyc', 'next', 'month', 'excited', 'ai', 'lets', 'catch', 'soon', 'cheers', 'john'], ['he
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Stem the words using PorterStemmer
stemmed_text = []
porter = PorterStemmer()
for words in tokenized_text:
    stemmed_words = [porter.stem(word) for word in words]
    stemmed_text.append(stemmed_words)
print(stemmed_text)
# Out:
# [['hey', 'cant', 'believ', 'alreadi', 'see', 'john', 'new', 'blog', 'post', 'check', 'also', 'email', 'johndoeexamplecom', 'mention', 'someth', 'stem', 'lemmatizationinterest', 'stuff', 'btw', 'ill', 'attend', 'ai', 'confer', 'nyc', 'next', 'month', 'excit', 'ai', 'let', 'catch', 'soon', 'cheer', 'john'], ['hey', 'cant', 'believ', 'alreadi', 'see', 'john', 'new', 'blog', 'post', 'check', 'also', 'email', 'johndoeexamplecom', 'mention', 'someth', 'stem', 'lemmatizationinterest', 'stuff', 'btw', 'ill', 'attend', 'ai', 'confer', 'nyc', 'next', 'month', 'excit', 'ai', 'let', 'catch', 'soon', 'cheer', 'john'], ['hey', 'cant', 'believ', 'alreadi', 'see', 'john', 'new', 'blog', 'post', 'check', 'also', 'email', 'johndoeexamplecom', 'mention', 'someth', 'stem', 'lemmatizationinterest', 'stuff', 'btw', 'ill', 'attend', 'ai', 'confer', 'nyc', 'next', 'month', 'excit', 'ai', 'let', 'catch', 'soon', 'cheer', 'john'], ['hey', 'cant', 'believ', 'alreadi', 'see', 'john', 'new', 'blog', 'post', 'che
# ...
